# %%
import nltk
import spacy
# nltk.download([
# "names",
# "stopwords",
# "state_union",
# "twitter_samples",
# "movie_reviews",
# "averaged_perceptron_tagger",
# "vader_lexicon",
# "punkt",
# ... ])
from nltk.tokenize import word_tokenize
import pandas as pd


data = pd.read_csv("data.csv")

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def tokenize(doc, lemmatized=False, remove_stopword=False, 
                   remove_punct = True, pos_tag = False):
    doc = doc.replace('\r\n', ' ').strip()
    t = nlp(doc)
    tokens = []
    for token in t:
        tokens.append((token.text.lower(),token.lemma_,token.is_stop,token.is_punct,token.pos_))
    if remove_stopword:
        tokens = [i for i in tokens if not i[2]]
    if remove_punct:
        tokens = [i for i in tokens if not i[3]]
    if lemmatized and pos_tag:
        tokens = [(i[1],i[4]) for i in tokens]
        return tokens
    if lemmatized:
        tokens = [i[1] for i in tokens]
        return tokens
    if pos_tag:
        tokens = [(i[0],i[4]) for i in tokens]
        return tokens 
    tokens = [i[0] for i in tokens]
    return tokens

# %%
data_analysis = data.copy()

# %%
data_analysis['transcript'] = data_analysis['transcript'].map(lambda x: x.replace('\r\n', ' ').strip())

# %%
token = tokenize(data.loc[100, 'transcript'], remove_stopword=True, remove_punct=True)
token
# Out:
# ['\r\n',
#  '23',
#  'iowa',
#  'activists',
#  'elected',
#  'officials',
#  'add',
#  'largest',
#  'coalitions',
#  'support',
#  '2020',
#  'presidential',
#  'campaign',
#  '\r\n',
#  'des',
#  'moines',
#  'ia',
#  'highly',
#  'successful',
#  'day',
#  'swing',
#  'state',
#  'iowa',
#  'lead',
#  'love',
#  'tour',
#  'cory',
#  'booker',
#  'locked',
#  '23',
#  'new',
#  'key',
#  'endorsements',
#  'help',
#  'propel',
#  'campaign',
#  'victory',
#  'caucus',
#  'night',
#  'including',
#  'johnson',
#  'county',
#  'supervisor',
#  'royceann',
#  'porter',
#  'mental',
#  'health',
#  'activists',
#  'leslie',
#  'scott',
#  'carpenter',
#  'polk',
#  'county',
#  'soil',
#  'water',
#  'commissioner',
#  'lou',
#  'mcdonald',
#  'dubuque',
#  'elected',
#  'official',
#  'danny',
#  'sprank',
#  '\r\n',
#  'excited',
#  'incredible',
#  'leaders',
#  'community',
#  'activists',
#  'corner',
#  'caucus',
#  'night',
#  'said',
#  'cory',
#  '2020',
#  'iowa',
# ...

# %%
token
# Out:
# ['\r\n',
#  'prepared',
#  'delivery',
#  '\r\n',
#  'hours',
#  'dawn',
#  'new',
#  'year',
#  'break',
#  'america',
#  'offering',
#  'moment',
#  'pause',
#  'reflection',
#  '\r\n',
#  'normally',
#  'moment',
#  'optimism',
#  'let',
#  'face',
#  'year',
#  'america',
#  'normal',
#  '\r\n',
#  'past',
#  '12',
#  'months',
#  'president',
#  'bolder',
#  'lies',
#  'brazen',
#  'law',
#  'breaking',
#  'tried',
#  'squeeze',
#  'foreign',
#  'government',
#  'advance',
#  'personal',
#  'political',
#  'fortunes',
#  '\r\n',
#  'republicans',
#  'congress',
#  'turned',
#  'fawning',
#  'spineless',
#  'defenders',
#  'crimes',
#  '\r\n',
#  'brought',
#  'joy',
#  'house',
#  'democrats',
#  'upheld',
#  'sworn',
#  'duty',
#  'constitution',
#  'impeached',
#  'president',
#  'united',
#  'states',
#  'soon',
#  'return',
#  'senate',
#  'sworn',
#  'duty',
#  '\r\n',
#  'senate',
#  'republicans',
#  'choose',
#  'truth',
#  'politics',
#  'donald',
#  'trump',
# ...

# %%
data.shape
# Out:
# (1205, 5)

# %%
data.head()
# Out:
#                                                title  \
# 0  Remarks at Old South Meeting House in Boston, ...
# 1  Steyer Campaign Press Release - Tom Steyer Rea...
# 2  Biden Campaign Press Release - Biden for Presi...
# 3  Article by Mike Bloomberg - You're In Charge: ...
# 4  Trump Campaign Statement - Happy New Year from...
#
#                         date             person  \
# 0  2019-12-31T00:00:00+00:00   Elizabeth Warren
# 1  2019-12-31T00:00:00+00:00         Tom Steyer
# 2  2019-12-31T00:00:00+00:00    Joseph R. Biden
# 3  2019-12-31T00:00:00+00:00  Michael Bloomberg
# 4  2019-12-31T00:00:00+00:00    Donald J. Trump
#
#                                                 link  \
# 0  /documents/remarks-old-south-meeting-house-bos...
# 1  /documents/steyer-campaign-press-release-tom-s...
# 2  /documents/biden-campaign-press-release-biden-...
# 3  /documents/article-mike-bloomberg-youre-charge...
# 4  /documents/trump-campaign-statement-happy-new-...
#
# ...

# %%
tokens = word_tokenize(data.loc[0,"transcript"])

# %%
tokens
# Out:
# ['[',
#  'As',
#  'prepared',
#  'for',
#  'delivery',
#  '.',
#  ']',
#  'In',
#  'a',
#  'few',
#  'hours',
#  ',',
#  'the',
#  'dawn',
#  'of',
#  'a',
#  'New',
#  'Year',
#  'will',
#  'break',
#  'over',
#  'America',
#  ',',
#  'offering',
#  'us',
#  'a',
#  'moment',
#  'for',
#  'pause',
#  'and',
#  'reflection',
#  '.',
#  'It',
#  'is',
#  'normally',
#  'a',
#  'moment',
#  'for',
#  'optimism',
#  '.',
#  'But',
#  'let',
#  "'s",
#  'face',
#  'it',
#  ':',
#  'This',
#  'year',
#  'in',
#  'America',
#  'has',
#  'been',
#  'anything',
#  'but',
#  'normal',
#  '.',
#  'In',
#  'the',
#  'past',
#  '12',
#  'months',
#  ',',
#  'the',
#  'president',
#  'has',
#  'become',
#  'bolder',
#  'with',
#  'his',
#  'lies',
#  'and',
#  'more',
#  'brazen',
#  'in',
#  'his',
#  'law-breaking',
#  '.',
#  'He',
#  'tried',
#  'to',
#  'squeeze',
#  'a',
#  'foreign',
#  'government',
#  'to',
#  'advance',
#  'his',
#  'own',
#  'personal',
#  'political',
#  'fortunes',
# ...

# %%
# Example using AFINN lexicon
from afinn import Afinn

afinn = Afinn()
sentiment_score = sum([afinn.score(word) for word in tokens])

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
sia.polarity_scores(data.loc[0,"transcript"])
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /Users/yashbhutoria/Desktop/webminingproject/process.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/Users/yashbhutoria/Desktop/webminingproject/process.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from nltk.sentiment import SentimentIntensityAnalyzer
# ----> <a href='vscode-notebook-cell:/Users/yashbhutoria/Desktop/webminingproject/process.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> sia = SentimentIntensityAnalyzer()
#       <a href='vscode-notebook-cell:/Users/yashbhutoria/Desktop/webminingproject/process.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> sia.polarity_scores(data.loc[0,"transcript"])
#
# File ~/Library/Python/3.9/lib/python/site-packages/nltk/sentiment/vader.py:340, in SentimentIntensityAnalyzer.__init__(self, lexicon_file)
#     336 def __init__(
#     337     self,
# ...

# %%
tokens[2]
# Out:
# 'prepared'

# %%
print(data.loc[0,"transcript"])
# Out:
# [As prepared for delivery.]
# In a few hours, the dawn of a New Year will break over America, offering us a moment for pause and reflection.
# It is normally a moment for optimism. But let's face it: This year in America has been anything but normal.
# In the past 12 months, the president has become bolder with his lies and more brazen in his law-breaking. He tried to squeeze a foreign government to advance his own personal political fortunes.
# Meanwhile, the Republicans in Congress have turned into fawning, spineless defenders of his crimes.
# It brought no one any joy, but the House Democrats upheld their sworn duty to the Constitution and impeached the president of the United States. Soon I will return to the Senate to do my sworn duty as well.
# But unless some Senate Republicans choose truth over politics, Donald Trump will be emboldened to try to cheat his way through yet another election.
# ...
