# %%
import pandas as pd 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import re

# %%
data = pd.read_csv("emotion_df.csv")
analyzer = SentimentIntensityAnalyzer()

# %%
data.head()
# Out:
#                                 processed_transcript  positive  trust
# 0  campaign continues growing super tuesday infra...      46.0   34.0  \
# 1  ring new year brad parscale campaign manager d...      17.0   10.0
# 2  celebration christmas day lara trump senior ad...      13.0    8.0
# 3  cárdenas fifth congressional hispanic caucus m...      33.0   25.0
# 4  des moines iowa today brent oleson linn county...      24.0   22.0
#
#    anticipation  joy  negative  sadness  anger  fear  surprise  disgust
# 0          10.0  9.0       4.0      4.0    2.0   2.0       1.0      0.0  \
# 1           8.0  8.0       1.0      1.0    0.0   0.0       7.0      0.0
# 2           5.0  9.0       0.0      1.0    0.0   1.0       6.0      0.0
# 3           6.0  5.0       1.0      0.0    0.0   1.0       1.0      2.0
# 4           3.0  2.0       5.0      0.0    1.0   2.0       2.0      0.0
#
#             person
# 0  Joseph R. Biden
# 1  Donald J. Trump
# 2  Donald J. Trump
# 3  Joseph R. Biden
# 4  Joseph R. Biden

# %%
raw_emotions_df = emotion_df.apply(lambda x: nrc_raw_emotions(x['processed_transcript']), axis=1, result_type='expand')
